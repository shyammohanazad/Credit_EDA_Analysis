# %% [markdown]
# <a href="https://colab.research.google.com/github/shyammohanazad/DataScienceProjects/blob/Churn_Prediction_In_Telecom_Using_MachineLearning/Churn_Prediction_In_Telecom_using_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1- Uploading Dataset from pC to Colab Direcly.**

# %%
import numpy as np
import pandas as pd
from google.colab import files
import io

uploaded=files.upload()

df=pd.read_csv(io.BytesIO(uploaded['WA_Fn_UseC_Telco-Customer-Churn.csv']))
df.head()
# Out:
#      <input type="file" id="files-de72bc84-19c4-4343-8b4a-51641d5e7c84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de72bc84-19c4-4343-8b4a-51641d5e7c84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **2- Uploading Dataset from oogle Drive to Google Colab Directly**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2.1- Checking If Drive is MOunted properly or not.**

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# **2.2- Loading Dataset from Drive to Colab**

# %%
df2=pd.read_csv("drive/My Drive/DataScience-DataSets/Churn_pred_data/WA_Fn_UseC_Telco-Customer-Churn.csv")
df2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
